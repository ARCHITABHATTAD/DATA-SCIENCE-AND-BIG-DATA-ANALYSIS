# %%
import pandas as pd
import numpy as np
import seaborn as sbs
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('onlineData.csv')

# %%
df.head()
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 0     Basic     Unemployment          Other      1.0       2051.36
# 1     Basic    self-employed           Card      0.0        544.04
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      1.0       1199.79
# 4     Basic    self-employed           Card      0.0           NaN

# %%
df.dtypes
# Out:
# Transaction_date     object
# Transaction_ID        int64
# Gender               object
# Age                 float64
# Marital_status       object
# State_names          object
# Segment              object
# Employees_status     object
# Payment_method       object
# Referal             float64
# Amount_spent        float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Transaction_date      0
# Transaction_ID        0
# Gender               28
# Age                  42
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             155
# Amount_spent        242
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Transaction_date      0
# Transaction_ID        0
# Gender               28
# Age                  42
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             155
# Amount_spent        242
# dtype: int64

# %%
# df = df[['Payment_method', 'Amount_spent']]

# %%
# df.describe()

# %%
# df.mean(numeric_only=True,skipna=True)

# %%
# df.median(numeric_only=True,skipna=True)

# %%
# df.mode(numeric_only=True)

# %%
# df.min()

# %%
# df.max()

# %%
# df.min()

# %%
# df.std(numeric_only=True,skipna=True)

# %%
# df.skew(numeric_only=True)

# %%
df
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
df['Payment_method'].isnull().sum()
# Out:
# 0

# %%
df['Payment_method'].value_counts()
# Out:
# PayPal    1168
# Card       749
# Other      595
# Name: Payment_method, dtype: int64

# %%
df_encoded = pd.get_dummies(df['Payment_method'])
df_encoded
# Out:
#       Card  Other  PayPal
# 0        0      1       0
# 1        1      0       0
# 2        0      0       1
# 3        1      0       0
# 4        1      0       0
# ...    ...    ...     ...
# 2507     1      0       0
# 2508     0      0       1
# 2509     0      0       1
# 2510     0      0       1
# 2511     0      0       1
#
# [2512 rows x 3 columns]

# %%
# df.groupby(by = 'Payment_method').mean()

# %%
# from sklearn.preprocessing import OneHotEncoder
# encoder = OneHotEncoder()
# encoded_results = encoder.fit_transform(df).toarray()
# encoded_results

# %%
# pd.crosstab(index=df['Payment_method'], columns=df['Amount_spent'])

# %%
# df.groupby(by="Payment_method", dropna=True).sum()

# %%
df
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
# data = df.groupby("Payment_method")["Amount_spent"]
# data.describe()

# %%
# data = df.groupby(by="Payment_method", level= None).describe()
# data

# %%
df['Payment_method'].unique()
# Out:
# array(['Other', 'Card', 'PayPal'], dtype=object)

# %%
group=df.groupby('Payment_method')

# %%
Other=group.get_group('Other')
Other
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 11           1/5/2019          151211  Female  63.0        Married
# 14           1/5/2019          151214    Male  24.0        Married
# 15           1/6/2019          151215    Male  16.0         Single
# 18           1/7/2019          151218    Male  42.0        Married
# ...               ...             ...     ...   ...            ...
# 2491        4/26/2021          153679    Male  75.0        Married
# 2495        4/27/2021          153683  Female  20.0        Married
# 2500        4/29/2021          153688  Female  73.0        Married
# 2504        4/30/2021          153692    Male  34.0        Married
# 2506        4/30/2021          153694    Male  34.0         Single
#
#       State_names   Segment Employees_status Payment_method  Referal  \
# 0          Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
Other.describe()
# Out:
#        Transaction_ID         Age     Referal  Amount_spent
# count      595.000000  588.000000  552.000000    544.000000
# mean    152453.458824   47.454082    0.675725   1450.188474
# std        723.826074   18.642506    0.468528    867.918732
# min     151200.000000   15.000000    0.000000      5.310000
# 25%     151840.500000   32.000000    0.000000    711.660000
# 50%     152462.000000   48.500000    1.000000   1404.940000
# 75%     153092.500000   63.000000    1.000000   2070.782500
# max     153694.000000   78.000000    1.000000   2987.960000

# %%
Card=group.get_group('Card')
Card
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 1            1/1/2019          151201    Male  49.0         Single
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# 8            1/4/2019          151208    Male  75.0        Married
# 9            1/4/2019          151209  Female  41.0        Married
# ...               ...             ...     ...   ...            ...
# 2497        4/28/2021          153685  Female  72.0        Married
# 2499        4/28/2021          153687    Male  33.0        Married
# 2501        4/29/2021          153689  Female  65.0         Single
# 2505        4/30/2021          153693    Male  54.0        Married
# 2507         5/1/2021          153695  Female  57.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 1           Illinois     Basic    self-employed           Card      0.0
# ...

# %%
Card.describe()
# Out:
#        Transaction_ID         Age     Referal  Amount_spent
# count      749.000000  734.000000  713.000000    668.000000
# mean    152461.696929   46.108992    0.635344   1395.286272
# std        734.625000   17.861422    0.481672    862.425415
# min     151201.000000   15.000000    0.000000     30.180000
# 25%     151795.000000   32.000000    0.000000    659.515000
# 50%     152486.000000   45.000000    1.000000   1308.015000
# 75%     153100.000000   61.000000    1.000000   1992.682500
# max     153695.000000   78.000000    1.000000   2999.980000

# %%
PayPal=group.get_group('PayPal')
PayPal
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2            1/1/2019          151202    Male  63.0        Married
# 5            1/3/2019          151205    Male  71.0         Single
# 6            1/3/2019          151206  Female  34.0        Married
# 7            1/3/2019          151207    Male  37.0        Married
# 10           1/4/2019          151210  Female  56.0        Married
# ...               ...             ...     ...   ...            ...
# 2503        4/29/2021          153691    Male  67.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2         New Mexico     Basic          workers         PayPal      1.0
# ...

# %%
PayPal.describe()
# Out:
#        Transaction_ID          Age      Referal  Amount_spent
# count     1168.000000  1148.000000  1092.000000   1058.000000
# mean    152427.684932    46.557491     0.651099   1416.697060
# std        718.724736    18.156954     0.476841    894.171343
# min     151202.000000    15.000000     0.000000      2.090000
# 25%     151819.250000    31.000000     0.000000    678.192500
# 50%     152401.000000    47.000000     1.000000   1325.535000
# 75%     153029.750000    62.000000     1.000000   2044.772500
# max     153699.000000    78.000000     1.000000   2998.620000
